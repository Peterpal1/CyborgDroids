# %%
import tensorflow as tf
print ("tensorflow:",tf.__version__)
# Out:
# WARNING:tensorflow:From c:\Users\Silfanus\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# tensorflow: 2.15.0

# %%
mnist = tf.keras.datasets.mnist
(x_train,x_test),(y_train,y_test) = mnist.load_data()
x_train, x_test = x_train/255.0 ,x_test/255.0

# %%
model = tf.keras.models.Sequential ([
        tf.keras.layers.Flatten(input_shape = (28,28)),
        tf.keras.layers.Dense(128, activation = "relu"),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10)
        ])
# Out:
# WARNING:tensorflow:From c:\Users\Silfanus\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[-0.7767826 ,  0.3696542 , -0.8752696 ,  0.02781369, -0.10827994,
#          0.3480868 , -0.2905947 , -0.69402623, -0.21161054, -0.24109565]],
#       dtype=float32)

# %%
tf.nn.softmax(predictions)
# Out:
# <tf.Tensor: shape=(1, 10), dtype=float32, numpy=
# array([[0.05405159, 0.17009817, 0.04898195, 0.1208482 , 0.10547158,
#         0.16646887, 0.08789359, 0.05871501, 0.0951173 , 0.0923537 ]],
#       dtype=float32)>

# %%
y_train.shape
# Out:
# (10000, 28, 28)

# %%
predictions.shape
# Out:
# (1, 10)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
loss_fn(y_train[:1], predictions).numpy()



model.compile(
    optimizer = 'adam',
loss = loss_fn,
metrics = ['accuracy']
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# ----> 2 loss_fn(y_train[:1], predictions).numpy()
#       6 model.compile(
#       7     optimizer = 'adam',
#       8 loss = loss_fn,
#       9 metrics = ['accuracy']
#      10 )
#
# File c:\Users\Silfanus\anaconda3\Lib\site-packages\keras\src\losses.py:143, in Loss.__call__(self, y_true, y_pred, sample_weight)
#     138 else:
#     139     call_fn = tf.__internal__.autograph.tf_convert(
#     140         self.call, tf.__internal__.autograph.control_status_ctx()
#     141     )
# --> 143 losses = call_fn(y_true, y_pred)
#     145 in_mask = losses_utils.get_mask(y_pred)
#     146 out_mask = losses_utils.get_mask(losses)
#
# File c:\Users\Silfanus\anaconda3\Lib\site-packages\keras\src\losses.py:270, in LossFunctionWrapper.call(self, y_true, y_pred)
#     263     y_pred, y_true = losses_utils.squeeze_or_expand_dimensions(
#     264         y_pred, y_true
#     265     )
#     267 ag_fn = tf.__internal__.autograph.tf_convert(
#     268     self.fn, tf.__internal__.autograph.control_status_ctx()
#     269 )
# --> 270 return ag_fn(y_true, y_pred, **self._fn_kwargs)
#
# File c:\Users\Silfanus\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\Users\Silfanus\anaconda3\Lib\site-packages\keras\src\losses.py:2454, in sparse_categorical_crossentropy(y_true, y_pred, from_logits, axis, ignore_class)
#    2403 @keras_export(
#    2404     "keras.metrics.sparse_categorical_crossentropy",
#    2405     "keras.losses.sparse_categorical_crossentropy",
#    (...)
#    2409     y_true, y_pred, from_logits=False, axis=-1, ignore_class=None
#    2410 ):
#    2411     """Computes the sparse categorical crossentropy loss.
#    2412
#    2413     Standalone usage:
#    (...)
#    2452         Sparse categorical crossentropy loss value.
#    2453     """
# -> 2454     return backend.sparse_categorical_crossentropy(
#    2455         y_true,
#    2456         y_pred,
#    2457         from_logits=from_logits,
#    2458         ignore_class=ignore_class,
#    2459         axis=axis,
#    2460     )
#
# File c:\Users\Silfanus\anaconda3\Lib\site-packages\keras\src\backend.py:5779, in sparse_categorical_crossentropy(target, output, from_logits, axis, ignore_class)
#    5775         res = tf.nn.sparse_softmax_cross_entropy_with_logits(
#    5776             labels=target, logits=output
#    5777         )
#    5778 else:
# -> 5779     res = tf.nn.sparse_softmax_cross_entropy_with_logits(
#    5780         labels=target, logits=output
#    5781     )
#    5783 if ignore_class is not None:
#    5784     res_shape = cast(output_shape[:-1], "int64")
#
# ValueError: `labels.shape` must equal `logits.shape` except for the last dimension. Received: labels.shape=(784,) and logits.shape=(1, 10)

# %%
model.fit(x_train, y_train, epochs=5)
model.evaluate(x_train,y_test,verbase=2)
